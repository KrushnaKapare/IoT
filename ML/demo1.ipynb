# %% [markdown]
# program1 -Header

# %%
print("Hello")
# Out:
# Hello

# %%
print("hello world")
# Out:
# hello world

# %%
num = 100 
print(num)
# Out:
# 100

# %%
num
# Out:
# 100

# %%
print(f"num = {num}")
# Out:
# num = 100

# %%
a = 10
b = 20
print(a+b)
# Out:
# 30

# %%
import numpy as np

# %%
def function1():
    arr= [10,20,30,40,50]
    print(arr)
    print(f"type = {type(arr)}")
    print(f"arr[0] type = {type(arr[0])}")

# %%
function1()
# Out:
# [10, 20, 30, 40, 50]
# type = <class 'list'>
# arr[0] type = <class 'int'>

# %%
def function2():
    arr = np.array([11,22,33,44,55])
    print(arr)
    print(f"type = {type(arr)}")
    print(f"arr[0] type = {type(arr[0])}")

# %%
function2()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 function2()
#
# Cell In[12], line 2, in function2()
#       1 def function2():
# ----> 2     arr = np.array[(11,22,33,44,55)]
#       3     print(arr)
#       4     print(f"type = {type(arr)}")
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
def function3():
    arr = np.array(10,20,30,40,50)
